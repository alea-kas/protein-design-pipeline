# %%
from pathlib import Path
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq

from chroma import Chroma

DATA_DIR = Path("..") / "data"
MOTIF_FASTA = DATA_DIR / "motif.fasta"

def load_motif(fasta_path: Path) -> str:
    records = list(SeqIO.parse(str(fasta_path), "fasta"))
    if not records:
        raise ValueError(f"No sequences found in {fasta_path}")
    return str(records[0].seq).upper()

motif = load_motif(MOTIF_FASTA)
motif
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 17
#      14         raise ValueError(f"No sequences found in {fasta_path}")
#      15     return str(records[0].seq).upper()
# ---> 17 motif = load_motif(MOTIF_FASTA)
#      18 motif
#
# Cell In[5], line 12, in load_motif(fasta_path)
#      11 def load_motif(fasta_path: Path) -> str:
# ---> 12     records = list(SeqIO.parse(str(fasta_path), "fasta"))
#      13     if not records:
#      14         raise ValueError(f"No sequences found in {fasta_path}")
#
# File ~\miniconda3\envs\chromaenv\lib\site-packages\Bio\SeqIO\__init__.py:674, in parse(handle, format, alphabet)
#     672 iterator_generator = _FormatToIterator.get(format)
#     673 if iterator_generator:
# --> 674     return iterator_generator(handle)
#     676 raise ValueError(f"Unknown format '{format}'")
#
# File ~\miniconda3\envs\chromaenv\lib\site-packages\Bio\SeqIO\FastaIO.py:196, in FastaIterator.__init__(self, source, alphabet)
#     194 if alphabet is not None:
#     195     raise ValueError("The alphabet argument is no longer supported")
# --> 196 super().__init__(source, fmt="Fasta")
#     197 line = self.stream.readline()
#     198 if not line:
#
# File ~\miniconda3\envs\chromaenv\lib\site-packages\Bio\SeqIO\Interfaces.py:82, in SequenceIterator.__init__(self, source, alphabet, fmt)
#      80 if isinstance(source, _PathLikeTypes):
#      81     mode = modes[0]
# ---> 82     self.stream = open(source, "r" + mode)
#      83 else:
#      84     value = source.read(0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\data\\motif.fasta'

# %%
def generate_with_motif(
    motif: str,
    chain_length: int = 60,
    n_wanted: int = 10,
    batch_size: int = 20,
    out_fasta: Path = DATA_DIR / "chroma_scaffolds_motif_10.fasta",
):
    chroma = Chroma()

    motif = motif.upper()
    if len(motif) > chain_length:
        raise ValueError("Motif is longer than desired chain length")

    records = []
    attempt = 0

    while len(records) < n_wanted:
        attempt += 1
        print(f"Sampling batch {attempt}...")

        protein = chroma.sample(
            chain_lengths=[chain_length] * batch_size,
            design_t=0.5,
            langevin_factor=8,
            inverse_temperature=8,
        )

        tmp_fasta = DATA_DIR / "_tmp_chroma_batch.fasta"
        protein.to_fasta(str(tmp_fasta))

        for rec in SeqIO.parse(str(tmp_fasta), "fasta"):
            seq = str(rec.seq).upper()
            if motif in seq:
                idx = len(records) + 1
                new_rec = SeqRecord(
                    Seq(seq),
                    id=f"chroma_motif_{idx}",
                    description=f"len={len(seq)}; motif_present",
                )
                records.append(new_rec)
                if len(records) >= n_wanted:
                    break

        tmp_fasta.unlink(missing_ok=True)
        print(f"Collected {len(records)} / {n_wanted} sequences with motif.")

    out_fasta.parent.mkdir(parents=True, exist_ok=True)
    SeqIO.write(records, str(out_fasta), "fasta")
    print(f"Saved {len(records)} sequences with motif to {out_fasta}")

generate_with_motif(motif=motif, chain_length=60, n_wanted=10)
